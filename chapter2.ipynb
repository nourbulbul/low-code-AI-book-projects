# %% [markdown]
# <a href="https://colab.research.google.com/github/nourbulbul/low-code-AI-book-projects/blob/main/chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# test

# %%
import pandas as pd

# %%
url='https://data.cdc.gov/api/views/jiwm-ppbh/rows.csv?accessType=DOWNLOAD'
heart_df=pd.read_csv(url, index_col=0)

# %%
heart_df.head()
# Out:
#      LocationAbbr LocationDesc GeographicLevel DataSource  \
# Year
# 2019           MO   Ray County          County       NVSS
# 2019           MT      Montana           State       NVSS
# 2019           MT      Montana           State       NVSS
# 2019           MT      Montana           State       NVSS
# 2019           MT      Montana           State       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       531.9
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 2019  Cardiovascular Diseases  Heart Disease Mortality       234.0
# 2019  Cardiovascular Diseases  Heart Disease Mortality       285.3
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
#
#                                         Data_Value_Type  \
# Year
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019                  Age-adjusted, 3-year Average Rate
# 2019                  Age-adjusted, 3-year Average Rate
# 2019                  Age-adjusted, 3-year Average Rate
# 2019                  Age-adjusted, 3-year Average Rate
#
#      Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# Year
# 2019                        NaN                 NaN                     Sex
# 2019                          ~   Insufficient Data                     Sex
# 2019                          ~   Insufficient Data                     Sex
# 2019                        NaN                 NaN                     Sex
# 2019                        NaN                 NaN                     Sex
#
#      Stratification1 StratificationCategory2 Stratification2 TopicID  \
# Year
# 2019            Male          Race/Ethnicity           Black      T2
# 2019            Male          Race/Ethnicity           Black      T2
# 2019          Female          Race/Ethnicity           Black      T2
# 2019         Overall          Race/Ethnicity        Hispanic      T2
# 2019            Male          Race/Ethnicity        Hispanic      T2
#
#       LocationID      Y_lat       X_lon
# Year
# 2019       29177  39.353614  -93.996813
# 2019          30  47.033200 -109.653000
# 2019          30  47.033200 -109.653000
# 2019          30  47.033200 -109.653000
# 2019          30  47.033200 -109.653000

# %%
heart_df = pd.read_csv('/content/heart.csv')

# %%
heart_df.head()
# Out:
#    Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 0  2019           MO   Ray County          County       NVSS
# 1  2019           MT      Montana           State       NVSS
# 2  2019           MT      Montana           State       NVSS
# 3  2019           MT      Montana           State       NVSS
# 4  2019           MT      Montana           State       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality       531.9
# 1  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 2  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 3  Cardiovascular Diseases  Heart Disease Mortality       234.0
# 4  Cardiovascular Diseases  Heart Disease Mortality       285.3
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 1  per 100,000 population                  Age-adjusted, 3-year Average Rate
# 2  per 100,000 population                  Age-adjusted, 3-year Average Rate
# 3  per 100,000 population                  Age-adjusted, 3-year Average Rate
# 4  per 100,000 population                  Age-adjusted, 3-year Average Rate
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# 0                        NaN                 NaN                     Sex
# 1                          ~   Insufficient Data                     Sex
# 2                          ~   Insufficient Data                     Sex
# 3                        NaN                 NaN                     Sex
# 4                        NaN                 NaN                     Sex
#
#   Stratification1 StratificationCategory2 Stratification2 TopicID  LocationID  \
# 0            Male          Race/Ethnicity           Black      T2     29177.0
# 1            Male          Race/Ethnicity           Black      T2        30.0
# 2          Female          Race/Ethnicity           Black      T2        30.0
# 3         Overall          Race/Ethnicity        Hispanic      T2        30.0
# 4            Male          Race/Ethnicity        Hispanic      T2        30.0
#
#        Y_lat       X_lon
# 0  39.353614  -93.996813
# 1  47.033200 -109.653000
# 2  47.033200 -109.653000
# 3  47.033200 -109.653000
# 4  47.033200 -109.653000

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4199 entries, 0 to 4198
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        4199 non-null   int64
#  1   LocationAbbr                4199 non-null   object
#  2   LocationDesc                4199 non-null   object
#  3   GeographicLevel             4199 non-null   object
#  4   DataSource                  4199 non-null   object
#  5   Class                       4199 non-null   object
#  6   Topic                       4199 non-null   object
#  7   Data_Value                  2685 non-null   float64
#  8   Data_Value_Unit             4199 non-null   object
#  9   Data_Value_Type             4199 non-null   object
#  10  Data_Value_Footnote_Symbol  1514 non-null   object
#  11  Data_Value_Footnote         1514 non-null   object
#  12  StratificationCategory1     4199 non-null   object
#  13  Stratification1             4199 non-null   object
#  14  StratificationCategory2     4199 non-null   object
#  15  Stratification2             4199 non-null   object
#  16  TopicID                     4198 non-null   object
#  17  LocationID                  4198 non-null   float64
#  18  Y_lat                       4198 non-null   float64
#  19  X_lon                       4198 non-null   float64
# dtypes: float64(4), int64(1), object(15)
# memory usage: 656.2+ KB

# %%
heart_df.isnull().sum()
# Out:
# Year                             0
# LocationAbbr                     0
# LocationDesc                     0
# GeographicLevel                  0
# DataSource                       0
# Class                            0
# Topic                            0
# Data_Value                    1514
# Data_Value_Unit                  0
# Data_Value_Type                  0
# Data_Value_Footnote_Symbol    2685
# Data_Value_Footnote           2685
# StratificationCategory1          0
# Stratification1                  0
# StratificationCategory2          0
# Stratification2                  0
# TopicID                          1
# LocationID                       1
# Y_lat                            1
# X_lon                            1
# dtype: int64

# %%
heart_df.Stratification2.unique()
# Out:
# array(['Black', 'Hispanic', 'Asian and Pacific Islander', 'White',
#        'Overall', 'American Indian and Alaskan Native', 'Asian and'],
#       dtype=object)

# %%
import seaborn as sns
sns.violinplot(x="Data_Value", y="Stratification2", data=heart_df)
# Out:
# <Axes: xlabel='Data_Value', ylabel='Stratification2'>

# %%
sns.displot(heart_df['Data_Value'])
